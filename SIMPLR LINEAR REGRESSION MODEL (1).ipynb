# %% [markdown]
# # James ndungu
#
# # week 7 assignment
#
# # linear regression model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
# Load dataset
df = pd.read_csv("C:\\Users\\ADMIN\\Downloads\\wk07-regression\\homeprices.csv")

# Preview data
print(df.head())

# Describe the data
print(df.describe())

# Visualize
plt.scatter(df['area'], df['price'], color='blue')
plt.xlabel("Area (sq ft)")
plt.ylabel("Price")
plt.title("Area vs Price")
plt.show()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
#               area          price
# count     5.000000       5.000000
# mean   3280.000000  626000.000000
# std     540.370243   74949.983322
# min    2600.000000  550000.000000
# 25%    3000.000000  565000.000000
# 50%    3200.000000  610000.000000
# 75%    3600.000000  680000.000000
# max    4000.000000  725000.000000

# %%
# Check for missing values
print(df.isnull().sum())

# Split features and target
X = df[['area']]  # Feature
y = df['price']   # Target

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
# Out:
# area     0
# price    0
# dtype: int64

# %%
# Create and train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Print coefficients
print(f"Intercept: {model.intercept_}")
print(f"Slope: {model.coef_[0]}")
# Out:
# Intercept: 213421.05263157905
# Slope: 127.6315789473684

# %%
# Make predictions
y_pred = model.predict(X_test)

# Evaluation Metrics
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = metrics.r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# MAE: 16184.21
# MSE: 490893351.80
# RMSE: 22156.11
# R² Score: 0.92

# %%
# Regression line
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel("Area (sq ft)")
plt.ylabel("Price")
plt.title("Regression Line: Area vs Price")
plt.legend()
plt.show()

# %%
# Example: Predict price based on user input
area_input = float(input("Enter the area in square feet: "))
predicted_price = model.predict([[area_input]])

print(f"Predicted Home Price for {area_input} sq ft: ${predicted_price[0]:,.2f}")
# Out:
# Enter the area in square feet:  2000
# Predicted Home Price for 2000.0 sq ft: $468,684.21
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
